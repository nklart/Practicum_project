# %% [markdown]
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# # Описание проекта

# %% [markdown]
# ## 1. Введение

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и нам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, нашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## 2. Описание данных

# %% [markdown]
# Данные для работы находятся в нескольких таблицах.

# %% [markdown]
# ### *market_file.csv*

# %% [markdown]
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Покупательская активность** — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - **Тип сервиса** — уровень сервиса, например «премиум» и «стандарт».
# - **Разрешить сообщать** — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - **Маркет_актив_6_мес** — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - **Маркет_актив_тек_мес** — количество маркетинговых коммуникаций в текущем месяце.
# - **Длительность** — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - **Акционные_покупки** — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - **Популярная_категория** — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - **Средний_просмотр_категорий_за_визит** — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - **Неоплаченные_продукты_штук_квартал** — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - **Ошибка_сервиса** — число сбоев, которые коснулись покупателя во время посещения сайта.
# - **Страниц_за_визит** — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# ### *market_money.csv*

# %% [markdown]
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Период** — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - **Выручка** — сумма выручки за период.

# %% [markdown]
# ### *market_time.csv*

# %% [markdown]
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Период** — название периода, во время которого зафиксировано общее время.
# - **минут** — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# ### *money.csv*

# %% [markdown]
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Прибыль** — значение прибыли.

# %% [markdown]
# ## 4. Как будем выполнять проект

# %% [markdown]
# Решать задачу нам нужно в два этапа:
#    1. Разработаем модель, которая предскажет вероятность снижения покупательской активности.
#    2. Выделим сегмент покупателей, проанализируем его и предложим, как увеличить его покупательскую активность. Используем данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся).\
#     Ниже несколько примеров сегментов:
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %% [markdown]
# **1.1** Загрузим данные. Файлы ***market_file.csv***, ***market_money.csv***, ***market_time.csv***, ***money.csv*** доступны по ссылкам в описании данных или через пути к ним:
# - **/datasets/market_file.csv**
# - **/datasets/market_money.csv**
# - **/datasets/market_time.csv**
# - **/datasets/money.csv**\
# В некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.

# %% [markdown]
# **1.2** Проверим, что данные в таблицах соответствуют описанию. Исследованием и объединением данных мы займемся позже.

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# Проведем необходимую предобработку данных.

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Проведем исследовательский анализ данных из каждой таблицы. Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформим выводы по результатам шага.

# %% [markdown]
# ### Шаг 4. Объединение таблиц

# %% [markdown]
# **4.1** Объединим таблицы **market_file.csv, market_money.csv, market_time.csv**. Данные о прибыли из файла money.csv при моделировании нам не понадобятся.

# %% [markdown]
# **4.2** Данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделаем отдельный столбец для каждого периода.

# %% [markdown]
# ### Шаг 5. Корреляционный анализ

# %% [markdown]
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделаем выводы о мультиколлинеарности и при необходимости устраним её.

# %% [markdown]
# ### Шаг 6. Использование пайплайнов

# %% [markdown]
# Применим все изученные модели. Для этого используем пайплайны.

# %% [markdown]
# **6.1** Во время подготовки данных используем ColumnTransformer. Количественные и категориальные признаки обработаем в пайплайне раздельно. Для кодирования категориальных признаков используем как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.

# %% [markdown]
# **6.2** Обучим четыре модели: **KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC()**. Для каждой из них подберем как минимум один гиперпараметр. Выберем подходящую для задачи метрику, аргументируя свой выбор. Используем эту метрику при подборе гиперпараметров.

# %% [markdown]
# **6.3** Выберем лучшую модель, используя заданную метрику. Для этого применим одну из стратегий:
# - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
# - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %% [markdown]
# ### Шаг 7. Анализ важности признаков

# %% [markdown]
# **7.1** Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.

# %% [markdown]
# **7.2** Сделаем выводы о значимости признаков:
# - какие признаки мало значимы для модели;
# - какие признаки сильнее всего влияют на целевой признак;
# - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %% [markdown]
# ### Шаг 8. Сегментация покупателей

# %% [markdown]
# **8.1** Выполним сегментацию покупателей, используя результаты моделирования и данные о прибыльности покупателей.

# %% [markdown]
# **8.2** Выберем группу покупателей и предложим, как увеличить её покупательскую активность:
# - Проведем графическое и аналитическое исследование группы покупателей.
# - Сделаем предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# **8.3** Сделаем выводы о сегментах:
# - какой сегмент мы взяли для дополнительного исследования,
# - какие предложения мы сделали и почему.

# %% [markdown]
# ### Шаг 9. Общий вывод

# %% [markdown]
# Сделаем общий вывод:
# - опишем задачу;
# - опишем исходные данные и проведённую предобработку;
# - напишем, что мы сделали для поиска лучшей модели;
# - укажем лучшую модель;
# - добавим выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# # Начало работы

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### 1.1 Импортируем необходимые инструменты

# %%
# !pip install -U -q numba

# %%
# !pip install -q scipy==1.12.0

# %%
# !pip install -q numpy==1.26.4

# %%
# !pip install -q shap

# %%
# !pip install -q phik

# %%
# !pip install -q matplotlib==3.8.4

# %%
# !pip install -q pandas==2.2.2

# %%
# !pip install -q seaborn==0.13.2

# %%
# !pip install -q scikit-learn==1.5.0

# %%
# загружаем основные библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import shap
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import roc_auc_score, recall_score, confusion_matrix

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 

# загружаем селекторы отбора признаков
from sklearn.feature_selection import SelectKBest, f_classif
from matplotlib import ticker
from phik import phik_matrix
from phik.report import plot_correlation_matrix
from sklearn.datasets import make_classification

# установка опции для отображения всех столбцов и чисел
pd.set_option('display.float_format', '{:,.2f}'.format)
pd.set_option("display.max.columns", None)
pd.set_option('display.max_colwidth', None)

plt.rcParams["figure.figsize"] = (10, 5) 



RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# ### 1.2 Загрузка датасетов для работы

# %%
# загрузим данные и изменим разделитель значений
market_file = pd.read_csv('/datasets/market_file.csv', sep=',', decimal='.')
market_money = pd.read_csv('/datasets/market_money.csv', sep=',', decimal='.')
market_time = pd.read_csv('/datasets/market_time.csv', sep=',', decimal='.')
money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# %%
# проверим соответствие данных описанию
# market_file
display(market_file.head())
market_file.info()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                3.40                     5           121               0.00
# 1                4.40                     4           819               0.75
# 2                4.90                     3           539               0.14
# 3                3.20                     5           896               0.99
# 4                5.10                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
# market_money
display(market_money.head())
market_money.info()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц 3,293.10
# 2  215348     предыдущий_месяц     0.00
# 3  215349  препредыдущий_месяц 4,472.00
# 4  215349        текущий_месяц 4,971.60
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
# market_time
display(market_time.head())
market_time.info()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
# money
display(money.head())
money.info()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# ### Вывод по разделу:

# %% [markdown]
# Мы загрузили данные и провели визуальный осмотр на соответствие описанию.
# 1. Данные соответствуют описанию
# 2. Необходимо изменить названия столбцов: привести к нижнему регистру и заменить пробел на нижнее подчеркивание
# 3. Исправить опечатки в данных
# 4. Пропуски отсутствуют

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
# Приведем столбцы таблиц к нижнему регистру для удобства дальнейшей работы
market_file.columns = market_file.columns.str.lower()
market_money.columns = market_money.columns.str.lower()
market_time.columns = market_time.columns.str.lower()
money.columns = money.columns.str.lower()

# %%
# переименуем столбцы market_file для удобства дальнейшей работы
market_file = market_file.rename(columns={'покупательская активность' : 'покупательская_активность',
                                        'тип сервиса':'тип_сервиса',
                                        'разрешить сообщать' : 'разрешить_сообщать'})

# %%
# выведем все уникальные значения типа str в датасете market_file
# проход по столбцам
for column in market_file.columns:
    # отбор значений типа str
    str_values = market_file[column][market_file[column].apply(lambda x: isinstance(x, str))]
    
    # проверка наличия строковых значений
    if not str_values.empty:
        unique_str_values = str_values.unique()
        print(f"Уникальные значения в столбце {column}: {unique_str_values}")
# Out:
# Уникальные значения в столбце покупательская_активность: ['Снизилась' 'Прежний уровень']
# Уникальные значения в столбце тип_сервиса: ['премиум' 'стандартт' 'стандарт']
# Уникальные значения в столбце разрешить_сообщать: ['да' 'нет']
# Уникальные значения в столбце популярная_категория: ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %%
# исправим опечатку
market_file['тип_сервиса'] = market_file['тип_сервиса'].str.replace('стандартт', 'стандарт')

# %%
# выведем все уникальные значения типа str в датасете market_file
print('Уникальные значения в столбце период:', market_money['период'].unique())
# Out:
# Уникальные значения в столбце период: ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %%
# выведем все уникальные значения типа str в датасете market_file
print('Уникальные значения в столбце период:', market_time['период'].unique())
# Out:
# Уникальные значения в столбце период: ['текущий_месяц' 'предыдцщий_месяц']

# %%
# исправим опечатку
market_time['период'] = market_time['период'].str.replace('предыдцщий_месяц', 'предыдущий_месяц')

# %% [markdown]
# ### Вывод по разделу:

# %% [markdown]
# 1. Мы привели названия столбцов к нижнему регистру.
# 2. После этого привели названия столбцов к "змеиному" регистру.
# 3. Вывели уникальные значения типа str и обнаружили опечатки:
#      - В столбце *тип_сервиса* датасета *market_money* имеются дубликаты - стандарт и стандартт.
#      - В столбце *период* датасета *market_time* имеется опечатка - предыдцщий_месяц.
# 4. Исправили опечатки.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### 3.1 *market_file* количественные признаки

# %%
market_file.describe()
# Out:
#               id  маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count   1,300.00            1,300.00              1,300.00      1,300.00
# mean  215,997.50                4.25                  4.01        601.90
# std       375.42                1.01                  0.70        249.86
# min   215,348.00                0.90                  3.00        110.00
# 25%   215,672.75                3.70                  4.00        405.50
# 50%   215,997.50                4.20                  4.00        606.00
# 75%   216,322.25                4.90                  4.00        806.00
# max   216,647.00                6.60                  5.00      1,079.00
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count           1,300.00                             1,300.00
# mean                0.32                                 3.27
# std                 0.25                                 1.36
# ...

# %% [markdown]
# По данным видим, что выбросы отсутствуют, значения лежат в пределах нескольких стандартных отклонений.

# %%
# создадим функцию для построения гистограмм количественных признаков
def plot_num_hist(df, labels):
    
    # получим список количественных признаков
    num_columns = df.select_dtypes(include='number').columns.tolist()
    
    # задаем область рисования
    fig, axs = plt.subplots(
        ncols=1,
        nrows=len(num_columns),
        figsize=(10, len(num_columns) * 5)
    )
    
    def plot_hist_once(column_name, label, ax):
        sns.histplot(
            data=df[column_name],
            ax=ax
        )
        
        # подписываем ось Y
        ax.set_ylabel('Количество клиентов')

        # подписываем ось X
        ax.set_xlabel(label)

        # устанавливаем в качестве названия графика название столбца
        title = f'Feature name: {column_name}'
        ax.set_title(title, fontsize=14, fontweight='bold')
        

    # если в датасете один признак для вывода, рисуем гистограмму 1 раз
    if len(num_columns) == 1:
        plot_hist_once(column_name=num_columns[0], label=labels[0], ax=axs)
        
        
    # если признаков больше 1, рисуем гистограмму в цикле для каждого признака
    else:          
        for i, ax in enumerate(axs):
            plot_hist_once(column_name=num_columns[i], label=labels[i], ax=ax)

# %%
# список подписей для оси Х из описания проекта
market_file_num_labels = [
    'Число рассылок, звонков, показов рекламы и прочего на клиента за 6 месяцев',
    'Число рассылок, звонков, показов рекламы и прочего на клиента за текущий месяц',
    'Cколько дней прошло с момента регистрации покупателя на сайте',
    'Cреднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев',
    'Cколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца',
    'Общее число неоплаченных товаров в корзине за последние 3 месяца',
    'Число сбоев, которые коснулись покупателя во время посещения сайта',
    'Cреднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца'
]

# %%
plot_num_hist(market_file.drop('id', axis=1), market_file_num_labels)

# %% [markdown]
# **Вывод:**
# ```
# - маркет_актив_6_мес: имеет нормальное распределение без выбросов
# - маркет_актив_тек_мес: имеет нормальное распределение без выбросов
# - длительность: имеет нормальное распределение без выбросов
# - акционные_покупки: имеет бимодальное распределение
# - средний_просмотр_категорий_за_визит: имеет нормальное распределение без выбросов
# - неоплаченные_продукты_штук_квартал: имеет нормальное распределение без выбросов
# - ошибка_сервиса: имеет нормальное распределение без выбросов
# - страниц_за_визит: имеет нормальное распределение без выбросов
# ```

# %% [markdown]
# ### 3.2 *market_file* категориальные признаки

# %%
market_file_cat_labels = [
    'Рассчитанный класс покупательской активности (целевой признак)',
    'Уровень сервиса',
    'Можно ли присылать покупателю дополнительные предложения о товаре',
    'Самая популярная категория товаров у покупателя за последние 6 месяцев'
]

# %%
# получаем список категориальных признаков
cat_columns = market_file.select_dtypes(exclude='number').columns.tolist()

# расчитываем соотношение высот для axes на основе количества уникальных категорий признака
bar_height_ratios = []
for col in cat_columns:
    bar_height_ratios.append(market_file[col].nunique())

# задаем область рисования
fig, axs = plt.subplots(
    ncols=1,

    # количество рядов задаем в соответствии с количеством категориальных признаков
    nrows=len(cat_columns),
    
    # сюда передаем сумму соотношений высот
    figsize=(9, sum(bar_height_ratios)),
    
    # сюда передаем список с соотношениями высот для каждого axes
    height_ratios = bar_height_ratios
)

fig.subplots_adjust(hspace=1) 

# в цикле по каждому объекту Axes отрисовываем количественные диаграммы для кажного признака
for i, feature_name in enumerate(cat_columns):
    sns.countplot(
        data=market_file,
        y=feature_name,
        
        # устанавливаем порядок по убыванию сверху вниз
        order=market_file[feature_name].value_counts().index,
        ax=axs[i]
    )
    
    # устанавливаем аннотации значений
    for p in axs[i].patches:
        x = p.get_width()
        y = p.get_y() + p.get_height() * 0.6
        axs[i].annotate(p.get_width(), (x, y), fontsize=10)
        pass


    # устанавливаем название и подписи осей графика
    title = f'Feature name: {cat_columns[i]}'
    axs[i].set_title(title, fontsize=14, fontweight='bold')
    axs[i].xaxis.set_major_formatter(ticker.NullFormatter())

    # этот код для автопереноса подписи оси X
    #wrapped_ylabel = "\n".join(textwrap.wrap(market_file_cat_labels[i], width=50))
    axs[i].set_xlabel(market_file_cat_labels[i])
    
plt.show()

# %% [markdown]
# **Вывод:**
# ```
# - покупательская_активность: несбалансирован
# - тип_сервиса: чаще используется стандарт, чем премиум
# - разрешить_сообщать: чаще разрешается присылать дополнительные предложения
# - популярная_категория: самой популярной категорией являются товары для детей, самой непопулярной кухонная посуда
# ```

# %% [markdown]
# ### 3.3 *market_money* количественные признаки

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_money.head()
# Out:
#        id               период  выручка
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц 3,293.10
# 2  215348     предыдущий_месяц     0.00
# 3  215349  препредыдущий_месяц 4,472.00
# 4  215349        текущий_месяц 4,971.60

# %%
print(market_money.columns)
# Out:
# Index(['id', 'период', 'выручка'], dtype='object')

# %%
# разделим признаки по периодам с помощью pivot_table()
market_money = market_money.pivot_table(
    index='id',
    columns='период',
    values='выручка',
    aggfunc='first'
).reset_index()

# %%
market_money.head()
# Out:
# период      id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# 0       215348              0.00                 0.00       3,293.10
# 1       215349          5,216.00             4,472.00       4,971.60
# 2       215350          5,457.50             4,826.00       5,058.40
# 3       215351          6,158.00             4,793.00       6,610.40
# 4       215352          5,807.50             4,594.00       5,872.50

# %%
market_money.describe()
# Out:
# период         id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# count    1,300.00          1,300.00             1,300.00       1,300.00
# mean   215,997.50          4,936.92             4,825.21       5,314.96
# std        375.42            739.60               405.98       2,939.71
# min    215,348.00              0.00                 0.00       2,758.70
# 25%    215,672.75          4,496.75             4,583.00       4,706.05
# 50%    215,997.50          5,005.00             4,809.00       5,179.95
# 75%    216,322.25          5,405.62             5,053.50       5,761.73
# max    216,647.00          6,869.50             5,663.00     106,862.20

# %% [markdown]
# По полученным данным видим нулевые значения в строке минимум у столбцов *предыдущий месяц* и *препредыдущий_месяц*.\
# В столбце *текущий_месяц* наблюдается выброс 106,862.20

# %%
# создадим список с названиями для оси Х
market_money_labels = [
    'Cумма выручки за предыдущий месяц',
    'Cумма выручки за препредыдущий месяц',
    'Cумма выручки за текущий месяц'
]

# %%
# используем функцию для построения гистограмм. Удалим столбец ID
plot_num_hist(market_money.drop('id', axis=1), market_money_labels)

# %% [markdown]
# На первых двух гистограммах также видим нулевые значения, на третьей - выброс.\
# Построим боксплоты.

# %%
ax = sns.boxplot(
    data=market_money.drop('id', axis=1),
    orient='h'
)
ax.set_xlabel('Выручка')
plt.show()

# %% [markdown]
# И изменим масштаб

# %%
ax = sns.boxplot(
    data=market_money.drop('id', axis=1),
    orient='h'
)
ax.set_xlim([-1000, 10000])
ax.set_xlabel('Выручка')
plt.show()

# %% [markdown]
# **Вывод:**
# - предыдущий_месяц: нулевые значения
# - препредыдущий месяц: нулевые значения
# - текущий_месяц: выброс 106862 на фоне среднего 5179\
# Выбросы будут мешаться и при обучении модели, и при тестировании. Удалим в шаге с объединением таблиц, чтобы не удалять один и тот же ID несколько раз

# %% [markdown]
# ### 3.4 *market_time* количественные признаки

# %%
market_time.head()
# Out:
#        id            период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдущий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдущий_месяц     12
# 4  215350     текущий_месяц     13

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
# так же формируем сводную таблицу
market_time = market_time.pivot_table(
    index='id',
    columns='период',
    values='минут',
    aggfunc='first'
).reset_index()

# %%
market_time.head()
# Out:
# период      id  предыдущий_месяц  текущий_месяц
# 0       215348                13             14
# 1       215349                12             10
# 2       215350                 8             13
# 3       215351                11             13
# 4       215352                 8             11

# %%
# сохраним в список подписи оси Х
market_time_labels = [
    'Значение времени, проведённого на сайте, в минутах за предыдущий месяц',
    'Значение времени, проведённого на сайте, в минутах за текущий месяц',
]

# %%
# используем ранее созданную функцию для построения гистограмм. Удалим столбец ID.
plot_num_hist(market_time.drop('id', axis=1), market_time_labels)

# %% [markdown]
# **Вывод:**
# - датасет market_time имеет нормальное распределение без выбросов

# %% [markdown]
# ### 3.5 *money* количественные признаки

# %%
money.head()
# Out:
#        id  прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money.describe()
# Out:
#               id  прибыль
# count   1,300.00 1,300.00
# mean  215,997.50     4.00
# std       375.42     1.01
# min   215,348.00     0.86
# 25%   215,672.75     3.30
# 50%   215,997.50     4.04
# 75%   216,322.25     4.67
# max   216,647.00     7.43

# %%
# сохраним в список название подписей оси Х
money_labels = ['Среднемесячная прибыль от покупателя за последние 3 месяца']

# %%
# используем функцию для построения гистограмм, удалив столбец ID
plot_num_hist(money.drop('id', axis=1), money_labels)

# %%
number_in = market_file.select_dtypes(include='number').columns.tolist()
number_ex = market_file.select_dtypes(exclude='number').columns.tolist()

# %%
number_ex
# Out:
# ['покупательская_активность',
#  'тип_сервиса',
#  'разрешить_сообщать',
#  'популярная_категория']

# %%
number_in.remove('id')
number_ex.remove('покупательская_активность')

# %%
for feature in number_in:
       plt.figure(figsize=(10, 6))
       sns.boxplot(x='покупательская_активность', y=feature, data=market_file)
       plt.title(f'ящиковая диаграмма для {feature} по категориям покупательской активности')
       plt.xlabel('Категории покупательской активности')
       plt.ylabel(feature)
       plt.grid(True)
       plt.show()

# %% [markdown]
# **Вывод:**
# **маркет_актив_6_мес**:
# - Вторая категория покупательской активности характеризуется более высокими значениями медианы и шире интерквартильным размахом, чем первая категория. Это может означать, что вторая группа имеет более высокую покупательскую активность в среднем.
# - Первая категория имеет более узкое распределение и средние значения на более низком уровне, что означает меньшую вариабельность данных.
#
# **маркет_актив_тек_мес**:
# - Данная диаграмма показывает узкое распределение значений в пределах IQR, что свидетельствует о небольшой вариабельности признака "маркет_актив_тек_мес" в данной категории покупательской активности.
#
# **длительность**:
# - Оба боксплота имеют схожие характеристики медианы и IQR, что указывает на относительно стабильное поведение в обоих сегментах.
# **акционные_покупки**:
# - В категории "Снизилась" наблюдается существенно большее разнообразие в объемах акционных покупок, чем в категории "Прежний уровень".
# - В категории "Прежний уровень" участники в основном совершают меньше акционных покупок, с несколькими значимыми выбросами.
#
# **средний_просмотр_категорий_за_визит**:
# - В категории "Прежний уровень" пользователи в среднем просматривают больше категорий за визит, чем в категории "Снизилась".
#
# **неоплаченные_продукты_штук_квартал**:
# - В категории "Снизилась" среднее число неоплаченных продуктов выше, чем в категории "Прежний уровень".
#
# **ошибка_сервиса**:
# - В категории "Прежний уровень" медиана значений ошибок сервиса выше, чем в категории "Снизилась".
# - Разброс данных в обеих категориях примерно одинаков, но в категории "Снизилась" есть более широкое распределение данных ниже медианы.
#
# **страниц_за_визит**:
# - Категория "Прежний уровень" имеет большее среднее число страниц за визит по сравнению с категорией "Снизилась".
# - В категории "Снизилась" присутствуют более низкие значения с несколькими выбросами.

# %%
# Построение столбчатой диаграммы для 'category1'
for feature in number_ex:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, hue='покупательская_активность', data=market_file)
    plt.title(feature)
    plt.xticks(rotation=45)
    plt.xlabel('Признаки')
    plt.ylabel('Клиенты')
    plt.legend(title='Target')
    plt.show()

# %% [markdown]
# **Вывод:**\
# Высокий процент клиентов, снижающих активность в:
#  - тип_сервиса: премиум
#  - разрешить_сообщать: нет
#  - популярная_категория:
#      - товары для детей
#      - домашний текстиль
#      - косметика и аксессуары
#      - кухонная посуда\
#
# В остальных признаках **прежний уровень** гораздо выше, чем **сниженная** покупательская активность

# %% [markdown]
# **Вывод:**
# - Данные нормально распределены, выбросы отсутствуют

# %% [markdown]
# ### Вывод по разделу:

# %% [markdown]
# Мы провели исследовательский анализ данных и выяснили, что в основном данные распределены нормально, выбросы отсутствуют, но есть исключения в таблице *market_money*: минимальные значения в двух столбцах равны нулю и есть один выброс в третьем столбце.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %% [markdown]
# Таблицы будем объединять по признаку ID

# %%
df_market = market_file \
    .merge(market_money, on='id') \
    .merge(market_time, on='id') \
    .set_index('id')

# %%
df_market.head()
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215348                3.40                     5           121
# 215349                4.40                     4           819
# 215350                4.90                     3           539
# 215351                3.20                     5           896
# 215352                5.10                     3          1064
#
#         акционные_покупки популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %%
# переименуем столбцы 
df_market = df_market.rename(columns={'предыдущий_месяц_x':'предыдущий_месяц_выручка',
                                      'препредыдущий_месяц':'препредыдущий_месяц_выручка',
                                      'текущий_месяц_x':'текущий_месяц_выручка',
                                      'предыдущий_месяц_y':'предыдущий_месяц_минут',
                                      'текущий_месяц_y':'текущий_месяц_минут'})

# %%
df_market.head()
# Out:
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215348                 Снизилась     премиум                 да
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
#
#         маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# id
# 215348                3.40                     5           121
# 215349                4.40                     4           819
# 215350                4.90                     3           539
# 215351                3.20                     5           896
# 215352                5.10                     3          1064
#
#         акционные_покупки популярная_категория  \
# id
# 215348               0.00     Товары для детей
# 215349               0.75     Товары для детей
# ...

# %%
# удалим выбросы, обнаруженные ранее 
drop_id = market_money.query('текущий_месяц > 100000')['id']

# %%
df_market = df_market.drop(drop_id)

# %%
drop_null = market_money.loc[(market_money == 0).any(axis=1), 'id']

# %%
df_market = df_market.drop(drop_null)

# %%
df_market.describe()
# Out:
#        маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count            1,296.00              1,296.00      1,296.00
# mean                 4.26                  4.01        602.97
# std                  1.01                  0.70        249.20
# min                  0.90                  3.00        121.00
# 25%                  3.70                  4.00        409.50
# 50%                  4.20                  4.00        606.50
# 75%                  4.90                  4.00        806.25
# max                  6.60                  5.00      1,079.00
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count           1,296.00                             1,296.00
# mean                0.32                                 3.27
# std                 0.25                                 1.36
# min                 0.11                                 1.00
# 25%                 0.17                                 2.00
# ...

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 215349 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   покупательская_активность            1296 non-null   object
#  1   тип_сервиса                          1296 non-null   object
#  2   разрешить_сообщать                   1296 non-null   object
#  3   маркет_актив_6_мес                   1296 non-null   float64
#  4   маркет_актив_тек_мес                 1296 non-null   int64
#  5   длительность                         1296 non-null   int64
#  6   акционные_покупки                    1296 non-null   float64
#  7   популярная_категория                 1296 non-null   object
#  8   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  9   неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  10  ошибка_сервиса                       1296 non-null   int64
# ...

# %% [markdown]
# ### Вывод по разделу:
# Мы объединили все датасеты, кроме *money*, удалили выбросы и переименовали столбцы

# %% [markdown]
# ## Шаг 5. Корреляционный анализ

# %% [markdown]
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования.

# %%
# создаём список с наименованиями непрерывных признаков
interval_cols = df_market.select_dtypes(include='number').columns.to_list()
# считаем корреляции на тренировочной выборке
phik_overview = phik_matrix(df_market, interval_cols=interval_cols)

# %%
plot_correlation_matrix(
    # функции передаём значения матрицы корреляции
    phik_overview.values,
    # указываем наименования столбцов
    x_labels=phik_overview.columns,
    # указываем наименования строк
    y_labels=phik_overview.index,
    # указываем цвет градиентной отрисовки
    vmin=0, vmax=1, color_map='Greens',
    # добавляем заголовок
    title=r'correlation $\phi_K$',
    # увеличиваем размер шрифта
    fontsize_factor=1.5,
    # увеличиваем размер графика
    figsize=(20, 15)
)

# %% [markdown]
# ### Вывод по разделу:
# Самые высокие коэффициенты корреляции между:
# - покупательская_активность и страниц_за_визит;
# - покупательская_активность и предыдущий_месяц_минут;
# - предыдущий_месяц_выручка и текущий_месяц_выручка;

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %% [markdown]
# **Для начала подготовим данные**

# %% [markdown]
# Нам необходимо устранить ошибку второго рода, чтобы клиенты со статусом "покупательская активность: снизилась" не определялись как клиенты со статусом "покупательская активность: осталась прежней".
# Мы используем 3 метрики: **accuracy**, **roc_auc** и **f1**.

# %% [markdown]
# **Закодируем целевой признак**

# %%
# закодируем целевой признак.
df_market['покупательская_активность'] = \
(df_market['покупательская_активность'] == 'Снизилась').astype(int)

# %% [markdown]
# **Акционные_покупки имеют бимодальное распределние, поэтому мы возьмем границу 0.6 и преобразуем в категориальных признак**

# %%
df_market['акционные_покупки'] = df_market['акционные_покупки'] > 0.6

# %%
# разделим датасет на входные и целевой признаки
X = df_market.drop('покупательская_активность', axis=1)
y = df_market['покупательская_активность']

# %%
# разделим выборку на тренировочную и тестовую
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify=y
)

# %%
# инициализируем OneHotEncoder()
ohe_encoder = OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# %%
# инициализируем OrdinalEncoder()
ord_encoder = OrdinalEncoder(categories=[[False, True]], handle_unknown='use_encoded_value', unknown_value=np.nan)

# %%
# инициализируем ColumnTransformer()
df_preprocessor_ = ColumnTransformer(
    [
        # передаем OneHotEncoder()
        ('ohe', ohe_encoder, X_train.select_dtypes(exclude='number').columns.to_list()),
        ('num', None, X_train.select_dtypes(include='number').columns.to_list())
    ], 
    remainder='passthrough'
)

# %%
# инициализируем списки с названиями признаков
ohe_columns = X_train.select_dtypes(exclude='number').columns.to_list()
ord_columns = ['акционные_покупки']

# %%
# инициализируем ColumnTransformer() c OrdinalEncoder
df_preprocessor_ord = ColumnTransformer(
    [
        # передаем OneHotEncoder()
        ('ohe', ohe_encoder, ohe_columns),
        ('ord', ord_encoder, ord_columns),
        ('num', None, X_train.select_dtypes(include='number').columns.to_list())
    ], 
    remainder='passthrough'
)

# %%
# инициализируем пайплайн
pipeline = Pipeline(
    [
        ('preprocessor', None),
        ('selector', SelectKBest(score_func=f_classif)),
        ('classifier', None)
    ]
)

# %%
# инициализируем список параметров
selector_k_range = range(15, 20)
# инициализируем скейлеры
scalers = [StandardScaler(), MinMaxScaler(), 'passthrough']
# инициализируем список column_transformers
column_transformers = [df_preprocessor_, df_preprocessor_ord]

# %%
# инициализируем словари с гиперпараметрами
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'classifier' : [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'classifier__min_samples_split' : range(2, 4),
        'classifier__min_samples_leaf' : range(1, 3),
        'classifier__max_depth' : range(3, 5),
        'classifier__max_features' : range(3, 5),
        'preprocessor' : column_transformers,
        'preprocessor__num' : scalers,
        'selector__k' : selector_k_range
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'classifier' : [KNeighborsClassifier()],
        'classifier__n_neighbors' : range(3, 6),
        'preprocessor' : column_transformers,
        'preprocessor__num' : scalers,
        'selector__k' : selector_k_range
    },

    # словарь для модели LogisticRegression()
    {
        'classifier' : [
            LogisticRegression(
                class_weight='balanced',
                random_state=RANDOM_STATE,
                solver='liblinear',
                penalty='l1'
            )
        ],
        'classifier__C' : range(2, 7),
        'preprocessor' : [df_preprocessor_ord],
        'preprocessor__num' : scalers,
        'selector__k' : selector_k_range
    },
    
    # словарь для модели SVC()
    {
        'classifier': [SVC(probability=True, random_state=RANDOM_STATE)],
        'classifier__kernel': ['rbf', 'poly'],
        'classifier__degree': range(1, 4),
        'classifier__C': range(1, 4),
        'preprocessor' : column_transformers,
        'preprocessor__num': scalers,
        'selector__k' : selector_k_range
    }
]

# %%
# инициализация объекта GridSearchCV
grid_cv = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    cv=5,
    # используем recall
    scoring={
        'accuracy': 'accuracy',
        'f1': 'f1',
        'roc_auc': 'roc_auc'
    },
    refit = 'accuracy',
    n_jobs=-1
)

# %%
# обучение модели на тренировочных данных
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor', None),
#                                        ('selector', SelectKBest()),
#                                        ('classifier', None)]),
#              n_jobs=-1,
#              param_grid=[{'classifier': [DecisionTreeClassifier(random_state=42)],
#                           'classifier__max_depth': range(3, 5),
#                           'classifier__max_features': range(3, 5),
#                           'classifier__min_samples_leaf': range(1, 3),
#                           'classifier__min_samples_split': range(2, 4)...
#                                                                              'неоплаченные_продукты_штук_квартал',
#                                                                              'ошибка_сервиса',
#                                                                              'страниц_за_визит',
# ...

# %%
results_df = pd.DataFrame(grid_cv.cv_results_)
print(results_df.columns)
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_classifier', 'param_classifier__max_depth',
#        'param_classifier__max_features', 'param_classifier__min_samples_leaf',
#        'param_classifier__min_samples_split', 'param_preprocessor',
#        'param_preprocessor__num', 'param_selector__k',
#        'param_classifier__n_neighbors', 'param_classifier__C',
#        'param_classifier__degree', 'param_classifier__kernel', 'params',
#        'split0_test_accuracy', 'split1_test_accuracy', 'split2_test_accuracy',
#        'split3_test_accuracy', 'split4_test_accuracy', 'mean_test_accuracy',
#        'std_test_accuracy', 'rank_test_accuracy', 'split0_test_f1',
#        'split1_test_f1', 'split2_test_f1', 'split3_test_f1', 'split4_test_f1',
#        'mean_test_f1', 'std_test_f1', 'rank_test_f1', 'split0_test_roc_auc',
#        'split1_test_roc_auc', 'split2_test_roc_auc', 'split3_test_roc_auc',
# ...

# %%
pd.DataFrame(grid_cv.cv_results_).sort_values(by='rank_test_accuracy', ascending=True).head(100)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 705            0.07          0.01             0.02            0.00
# 645            0.07          0.00             0.02            0.00
# 765            0.07          0.01             0.02            0.00
# 888            0.07          0.00             0.02            0.00
# 828            0.07          0.00             0.02            0.00
# ...             ...           ...              ...             ...
# 1020           0.08          0.00             0.02            0.00
# 1140           0.07          0.00             0.02            0.00
# 1174           0.06          0.00             0.02            0.00
# 797            0.05          0.00             0.01            0.00
# 770            0.07          0.00             0.02            0.00
#
#                             param_classifier  param_classifier__max_depth  \
# 705   SVC(probability=True, random_state=42)                          NaN
# ...

# %%
pd.DataFrame(grid_cv.cv_results_).sort_values(by='rank_test_f1', ascending=True).head(100)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1007           0.07          0.00             0.02            0.00
# 1127           0.07          0.01             0.02            0.00
# 1067           0.07          0.00             0.02            0.00
# 948            0.07          0.00             0.02            0.00
# 888            0.07          0.00             0.02            0.00
# ...             ...           ...              ...             ...
# 557            0.01          0.00             0.02            0.00
# 525            0.01          0.00             0.03            0.00
# 710            0.07          0.00             0.02            0.00
# 770            0.07          0.00             0.02            0.00
# 650            0.06          0.00             0.02            0.00
#
#                             param_classifier  param_classifier__max_depth  \
# 1007  SVC(probability=True, random_state=42)                          NaN
# ...

# %%
pd.DataFrame(grid_cv.cv_results_).sort_values(by='rank_test_roc_auc', ascending=True).head(100)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 663           0.07          0.00             0.02            0.00
# 783           0.07          0.00             0.02            0.00
# 723           0.07          0.00             0.02            0.00
# 647           0.07          0.01             0.02            0.00
# 707           0.07          0.01             0.02            0.00
# ..             ...           ...              ...             ...
# 797           0.05          0.00             0.01            0.00
# 813           0.05          0.00             0.02            0.00
# 978           0.06          0.00             0.01            0.00
# 846           0.06          0.00             0.02            0.00
# 906           0.06          0.00             0.02            0.00
#
#                            param_classifier  param_classifier__max_depth  \
# 663  SVC(probability=True, random_state=42)                          NaN
# ...

# %%
# Выбор лучшей модели
best_index = grid_cv.best_index_
best_results = results_df.iloc[best_index]

# Визуализация
metrics = ['mean_test_accuracy', 'mean_test_roc_auc', 'mean_test_f1']
scores = [best_results[metric] for metric in metrics]

plt.bar(metrics, scores)
plt.title('Баланс accuracy, roc_auc и F1')
plt.ylim(0, 1)
plt.show()
# Out:
# PermutationExplainer explainer:  13%|█▎        | 122/972 [07:12<57:46,  4.08s/it]

# %%
# инициализируем лучшую модель
pipeline = grid_cv.best_estimator_

# обучаем модель и получаем прогнозы на тестовой выборке
y_pred = pipeline.fit(X_train, y_train).predict(X_test)

# %%
# посчитаем параметры
print("Лучшие параметры: ", grid_cv.best_params_)
print(f'Лучшая метрика на кросс-валидации: {grid_cv.best_score_}')
print(f'Метрика на тестовой выборке: {recall_score(y_test, y_pred)}')
# Out:
# Лучшие параметры:  {'classifier': SVC(probability=True, random_state=42), 'classifier__C': 1, 'classifier__degree': 1, 'classifier__kernel': 'rbf', 'preprocessor': ColumnTransformer(remainder='passthrough',
#                   transformers=[('ohe',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['тип_сервиса', 'разрешить_сообщать',
#                                   'акционные_покупки',
#                                   'популярная_категория']),
#                                 ('num', None,
#                                  ['маркет_актив_6_мес', 'маркет_актив_тек_мес',
#                                   'длительность',
#                                   'средний_просмотр_категорий_за_визит',
#                                   'неоплаченные_продукты_штук_квартал',
# ...

# %% [markdown]
# ### Вывод по разделу:
# - Лучшей моделью является SVC с параметрами:
#     - classifier__kernel = 'rbf'
#     - classifier__degree = 1
#     - random_state = 42
#     - classifier__C: 1
#     - preprocessor__num: StandardScaler()
#     - preprocessor: ColumnTransformer
#     - selector__k: 16
# - Лучшая метрика на кросс-валидации: 0.8878297647369813
# - Метрика на тестовой выборке: 0.7967479674796748

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %%
def prepare_features(X, preprocessor, selector):
    # инициализируем DataFrame с тренировочным набором
    X_transformed_selected = pd.DataFrame(
    
        # из Pipeline получаем ColumnTransformer, кодируем и масштабируем признаки
        data=preprocessor.transform(X),
    
        # из ColumnTransformer получаем новые названия признаков
        columns=pipeline['preprocessor'].get_feature_names_out()
    ).loc[:, selector.get_support()]
    # функция возвращаем подготовленный для модели набор данных
    return X_transformed_selected

# %%
# вызываем ранее определенную функцию для подготовки данных
X_train_transformed_selected = prepare_features(
    X=X_train,
    preprocessor=pipeline['preprocessor'],
    selector=pipeline['selector']
)

# %%
# функция принимает на вход модель и подготовленный для нее набор признаков
def plot_shap_beeswarm(model, X_transformed_selected):
    # используем библиотеку shap
    explainer = shap.Explainer(model, X_transformed_selected)
    shap_values = explainer(X_transformed_selected)
    shap.plots.beeswarm(
        shap_values,
        
        # передаем размерность в max_display
        max_display=len(X_transformed_selected)
    )

# %%
# функция принимает на вход модель и подготовленный для нее набор признаков
def plot_shap_bar(model, X_transformed_selected):
    # используем библиотеку shap
    explainer = shap.LinearExplainer(model, X_transformed_selected)
    shap_values = explainer(X_transformed_selected)
    shap.plots.bar(
        shap_values,
        # передаем размерность в max_display
        max_display=len(X_train_transformed_selected)
    )

# %% [markdown]
# Я не понял как построить график для модели SVC, через kernel explainer получается очень долго

# %% [markdown]
# ### Вывод по разделу:
# Рейтинг важных признаков по убыванию:
# 1. страниц за визит
# 2. средний просмотр категорий за визит
# 3. неоплаченные продукты штук квартал
# 4. предыдущий месяц минут
# 5. текущий месяц минут
# 6. маркет актив 6 мес
# 7. акционные покупки True
# 8. популярная категория мелкая бытовая техника и электроника

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %% [markdown]
# ### 8.1 Выделим сегменты

# %%
market = df_market
# задаем пределы
PROBA_THRESHOLD_1 = 0.9
PROBA_THRESHOLD_0 = 0.1
PROFIT_THRESHOLD = 2.4

# собираем данные для анализа в общий датафрейм
# выводим размерность до объединения
print('Shape before', market.shape)

# записываем столбец с вероятностями отнесения к классу 1 (снижение покупательской активности)
market['вероятность_снижения_активности'] = pipeline.predict_proba(market)[:, 1]

# записываем столбец с прогнозами лучшей модели
market['predicted_target'] = pipeline.predict(market)

# объединяем датасет с информацией о прибыли
market = market.merge(money, on='id', how='inner')

# выводим размерность полсе объединения
print('Shape after', market.shape)

# выводим случайные 10 строк нового датасета
market.sample(10)

# получаем срез по целевому сегменту
market_segment_target = market.query(
    f'вероятность_снижения_активности > {PROBA_THRESHOLD_1} and прибыль > {PROFIT_THRESHOLD}'
)

# получаем срез по сегменту для сравнения
market_segment_to_compare = market.query(
    f'вероятность_снижения_активности < {PROBA_THRESHOLD_0} and прибыль > {PROFIT_THRESHOLD}'
)
print('market_segment_target shape', market_segment_target.shape)
print('market_segment_to_compare shape', market_segment_to_compare.shape)
# Out:
# Shape before (1296, 17)
# Shape after (1296, 21)
# market_segment_target shape (323, 21)
# market_segment_to_compare shape (358, 21)

# %%
# рисуем диаграмму рассеяния по сегментам
plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=market,
    x='вероятность_снижения_активности',
    y='прибыль',
    alpha=0.5,
    label='Другие сегменты'
    
)
sns.scatterplot(
    data=market_segment_target,
    x='вероятность_снижения_активности',
    y='прибыль',
    alpha=0.5,
    color='red',
    label='Целевой сегмент'
)
sns.scatterplot(
    data=market_segment_to_compare,
    x='вероятность_снижения_активности',
    y='прибыль',
    alpha=0.5,
    color='green',
    label='Cегмент для сравнения'
)
plt.title(
    'Диаграмма рассеяния\nпо прибыли и вероятности снижения покупательской активности',
    fontsize=14,
    fontweight='bold'
)
plt.legend()
plt.axvline(x=PROBA_THRESHOLD_1, color='orange', linestyle='--')
plt.axvline(x=PROBA_THRESHOLD_0, color='orange', linestyle='--')
plt.axhline(y=PROFIT_THRESHOLD, color='orange', linestyle='--')
sns.despine(left=True)
plt.show()

# %% [markdown]
# Мы взяли группу клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.\
# На основе данной диаграммы можно сделать выводы о стратегии взаимодействия с различными клиентами:
# - Целевой сегмент стоит развивать и удерживать, так как они приносят стабильную прибыль и имеют низкий риск снижения активности.
# - Сегмент для сравнения можно рассмотреть для специальных программ лояльности или иных мер удержания, так как они приносят значительную прибыль, но подвержены высокому риску снижения активности.

# %% [markdown]
# ### 8.2 Сравним показатели

# %%
# инициализируем список названий необходимых количественных признаков
num_features = market_segment_target.select_dtypes(include='number').columns.to_list()
num_features.remove('id')
num_features.remove('predicted_target')
num_features.remove('покупательская_активность')
num_features.remove('вероятность_снижения_активности')

# %%
# задаем количество областей для рисования и их размеры
fig, axs = plt.subplots(
    ncols=2,
    nrows=6,
    figsize=(12, 24),
    layout='constrained'
)

# задаем цвета цвета и прозрачность
OPACITY = 0.5

counter = 0
for row in axs:
    for ax in row:
        sns.histplot(
            # передаем датасет с целевым сегментом
            data=market_segment_target,
            x=num_features[counter],
            ax=ax,
            label='Снизилась'
        )
        ax.grid = False
        counter += 1
    
counter = 0
for row in axs:
    for ax in row:
        sns.histplot(
            # передаем датасет с сегментом для сравнения
            data=market_segment_to_compare,
            x=num_features[counter],
            ax=ax,
            alpha=OPACITY,
            label='Осталась прежней'
        )
        ax.grid = False
        counter += 1

handles, labels = axs[0, 0].get_legend_handles_labels()

fig.legend(
    handles,
    labels,
    loc='upper right',
    title='Покупательская активность',
    fontsize=10
)

fig.suptitle(
    'Распределение количественных признаков для разных сегментов покупателей',
    fontsize=12,
    fontweight='bold'
)

sns.despine(left=True)
plt.show()

# %% [markdown]
# В сегменте со сниженной покупательской активностью покупатели меньше времени проводят на сайте, имеют больше неоплаченных товаров в корзине, меньше смотрят категорий и страниц и на них приходится меньшее количество маркетинговых коммуникаций

# %%
sns.countplot(
    data=pd.concat([market_segment_target, market_segment_to_compare], axis=0),
    x='тип_сервиса',
    hue='predicted_target'
)
plt.show()

# %% [markdown]
# Между категориями нет большой разницы

# %%
sns.countplot(
    data=pd.concat([market_segment_target, market_segment_to_compare], axis=0),
    x='разрешить_сообщать',
    hue='predicted_target'
)
plt.show()

# %% [markdown]
# Так же нет большой разницы

# %%
sns.countplot(
    data=pd.concat([market_segment_target, market_segment_to_compare], axis=0),
    x='акционные_покупки',
    hue='predicted_target'
)
plt.show()

# %% [markdown]
# В столбце с высокой вероятностью снижения покупательской активности покупок товаров по акции гораздо выше.

# %%
sns.countplot(
    data=pd.concat([market_segment_target, market_segment_to_compare], axis=0),
    y='популярная_категория',
    hue='predicted_target',
    orient='h',
    order=market_segment_target['популярная_категория'].value_counts().index
)
plt.show()

# %% [markdown]
# В столбце с высокой вероятностью снижения покупательской активности самыми непопулярными категориями товаров являются техника для красоты и здоровья и мелкая бытовая техника и электроника.

# %% [markdown]
# ### Вывод по разделу:
# Для исследования мы взяли сегмент покупателей с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.\
# Были отбраны признаки, которые удовлетворяют трем условиям:
# 1. Возможность влияния на показатели признака.
# 2. Высокая или средняя значимость.
# 3. Разница в показателях для двух сегментов.
# По данным критерям подходят:
# - неоплаченные продукты в корзине
# - маркет актив
# - мелкая бытовая техника и электроника
# - товары для красоты и здоровья

# %% [markdown]
# ## Шаг 9. Общий вывод

# %% [markdown]
# Перед нами стояла задача: разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность. На вход нам дали 4 датасета.\
#
# 1. На первом этапе мы импортировали необходимые для работы библиотеки, загрузили предоставленные датасеты и провели визуальный осмотр на соответствие данных описанию.
# 2. Далее мы занялись предобработкой данных:
#     - Привели названия столбцов к нижнему регистру;
#     - Привели названия столбцов к "змеиному" регистру;
#     - обнаружили и исправили опечатки в данных.
# 3. На этом этапе мы занялись исследовательским анализом данных: изучали данные с помощью метода describe() и строили гистограммы, сделали выводы.
# 4. Четвертым шагом мы объединили все датасеты в один (df_market), удалили выбросы и переименовали столбцы.
# 5. Пятым шагом мы построили матрицу корреляции для объединенного датасета и нашли самые высокие коэффициенты корреляции между признаками.
# 6. Далее мы создали пайплайн, который помог нам найти лучшую модель для прогнозирования.\
# Отбор был между четырьмя моделями по метрикам **accuracy**, **f1** и **roc_auc**:
#     - KNeighborsClassifier()
#     - DecisionTreeClassifier()
#     - LogisticRegression()
#     - SVC()\
# Лучшей оказалась модель SVC.
# 7. На седьмом этапе мы выделили признаки, имеющие наивысшую важность для модели.
# 8. И последним этапом было сегментирование покупателей. Мы провели графическое и аналитическое исследование группы покупателей.

# %% [markdown]
# **Рекомендации:**\
# Для увеличения покупательской активности нужно **увеличить количество маркетинговых рассылок** и **напоминаний о неоплаченных товарах в корзине**, а так же **чаще показывать** карточки товаров  **мелкой бытовой техники** и **товаров для красоты** *т.к. клиенты со сниженной покупательской активностью меньше времени проводят на сайте, имеют больше неоплаченных товаров в корзине, меньше смотрят категорий и страниц, на них приходится меньшее количество маркетинговых коммуникаций и самыми непопулярными товарами в сегменте клиентов со сниженной активностью являются категории мелкой бытовой техники и товары для красоты.*
